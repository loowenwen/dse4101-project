# %%
import pandas as pd
# %pip install openpyxl
import openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
expand = pd.read_csv("../pca_expandingwindow/summary_hit_days_all_expanding_30d.csv")
rolling_30d = pd.read_csv("../pca_rollingwindow_30/summary_hit_days_all_rolling_30d.csv")
rolling_60d = pd.read_csv("../pca_rollingwindow_60/summary_hit_days_all_rolling_60d.csv")
rolling_90d = pd.read_csv("../pca_rollingwindow_90/summary_hit_days_all_rolling_90d.csv")
summary_all = pd.concat([
    expand, rolling_30d, rolling_60d, rolling_90d
 ], ignore_index=True)
summary_all.to_excel("summary_hit_days_all.xlsx", index=False)
